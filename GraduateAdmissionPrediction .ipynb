# %% [markdown]
# Import the Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Load the dataset

# %%
dataset = pd.read_csv('Grad_Admission_Dataset.csv')
dataset
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 0           1              0.92
# 1           1              0.76
# 2           1              0.72
# 3           1              0.80
# 4           0              0.65
# ..        ...               ...
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95
#
# [400 rows x 9 columns]

# %% [markdown]
# Removing the extra columns

# %%
dataset.drop(['Serial No.'] , axis='columns' , inplace=True)

# %% [markdown]
# Exploring the dataset

# %%
dataset.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          400 non-null    int64
#  1   TOEFL Score        400 non-null    int64
#  2   University Rating  400 non-null    int64
#  3   SOP                400 non-null    float64
#  4   LOR                400 non-null    float64
#  5   CGPA               400 non-null    float64
#  6   Research           400 non-null    int64
#  7   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 25.1 KB

# %%
dataset.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP        LOR   \
# count  400.000000   400.000000         400.000000  400.000000  400.000000
# mean   316.807500   107.410000           3.087500    3.400000    3.452500
# std     11.473646     6.069514           1.143728    1.006869    0.898478
# min    290.000000    92.000000           1.000000    1.000000    1.000000
# 25%    308.000000   103.000000           2.000000    2.500000    3.000000
# 50%    317.000000   107.000000           3.000000    3.500000    3.500000
# 75%    325.000000   112.000000           4.000000    4.000000    4.000000
# max    340.000000   120.000000           5.000000    5.000000    5.000000
#
#              CGPA    Research  Chance of Admit
# count  400.000000  400.000000        400.000000
# mean     8.598925    0.547500          0.724350
# std      0.596317    0.498362          0.142609
# min      6.800000    0.000000          0.340000
# 25%      8.170000    0.000000          0.640000
# 50%      8.610000    1.000000          0.730000
# 75%      9.062500    1.000000          0.830000
# max      9.920000    1.000000          0.970000

# %% [markdown]
# Data Visualization - Exploring the pairwise correlation of the columns

# %%
corr = dataset.corr(method='pearson')
corr.style.background_gradient(cmap='PuBu')
# Out:
# <style  type="text/css" >
# #T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow0_col0,#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow1_col1,#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow2_col2,#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow3_col3,#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow4_col4,#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow5_col5,#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow6_col6,#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow7_col7{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow0_col1{
#             background-color:  #2182b9;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow0_col2{
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow0_col3,#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow0_col6{
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow0_col4{
#             background-color:  #cacee5;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow0_col5{
#             background-color:  #2c89bd;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow0_col7{
#             background-color:  #589ec8;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow1_col0{
#             background-color:  #348ebf;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow1_col2{
#             background-color:  #89b1d4;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow1_col3,#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow4_col2{
#             background-color:  #a2bcda;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow1_col4{
#             background-color:  #c5cce3;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow1_col5{
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow1_col6,#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow4_col1{
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow1_col7{
#             background-color:  #63a2cb;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow2_col0{
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow2_col1{
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow2_col3{
#             background-color:  #69a5cc;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow2_col4{
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow2_col5{
#             background-color:  #80aed2;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow2_col6{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow2_col7{
#             background-color:  #adc1dd;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow3_col0{
#             background-color:  #ede7f2;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow3_col1{
#             background-color:  #b5c4df;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow3_col2{
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow3_col4,#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow7_col0{
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow3_col5{
#             background-color:  #97b7d7;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow3_col6{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow3_col7{
#             background-color:  #c8cde4;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow4_col0,#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow4_col6,#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow6_col1,#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow6_col2,#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow6_col3,#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow6_col4,#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow6_col5,#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow6_col7{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow4_col3{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow4_col5{
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow4_col7,#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow7_col6{
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow5_col0{
#             background-color:  #3790c0;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow5_col1{
#             background-color:  #2786bb;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow5_col2{
#             background-color:  #60a1ca;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow5_col3{
#             background-color:  #76aad0;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow5_col4{
#             background-color:  #86b0d3;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow5_col6{
#             background-color:  #dad9ea;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow5_col7{
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow6_col0{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow7_col1{
#             background-color:  #4697c4;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow7_col2{
#             background-color:  #7dacd1;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow7_col3{
#             background-color:  #96b6d7;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow7_col4{
#             background-color:  #88b1d4;
#             color:  #000000;
#         }#T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow7_col5{
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }</style><table id="T_76cb1484_7719_11eb_bdba_f8ac65e0d65b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >GRE Score</th>        <th class="col_heading level0 col1" >TOEFL Score</th>        <th class="col_heading level0 col2" >University Rating</th>        <th class="col_heading level0 col3" >SOP</th>        <th class="col_heading level0 col4" >LOR </th>        <th class="col_heading level0 col5" >CGPA</th>        <th class="col_heading level0 col6" >Research</th>        <th class="col_heading level0 col7" >Chance of Admit </th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_76cb1484_7719_11eb_bdba_f8ac65e0d65blevel0_row0" class="row_heading level0 row0" >GRE Score</th>
#                         <td id="T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow0_col1" class="data row0 col1" >0.835977</td>
#                         <td id="T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow0_col2" class="data row0 col2" >0.668976</td>
#                         <td id="T_76cb1484_7719_11eb_bdba_f8ac65e0d65brow0_col3" class="data row0 col3" >0.612831</td>
#                         <td id="T_76cb1484_7

# %% [markdown]
# We can interpret the above correlation matrix as:
#
# 1) The higher the CGPA the higher is the chance of getting an admit
#
# 2) The higher the GRE score the higher is the chance of getting an admit

# %% [markdown]
# Visualizing correlation between all columns
#
# 1) By constructing pairplot

# %%
import seaborn as sns
sns.pairplot(dataset)

# %% [markdown]
# Applying Machine Learning Algorithms:
#
# 1) Multiple Linear Regression

# %%
x = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %% [markdown]
# Splitting into training and testing set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)

# %% [markdown]
# Training the LinearRegression Model

# %%
from sklearn.linear_model import LinearRegression
linearRegression = LinearRegression()
linearRegression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Predicting the test set result

# %%
y_pred = linearRegression.predict(X_test)
np.set_printoptions(precision=2)

# %% [markdown]
# Checking the accuracy with mean absolute error method

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, y_pred)*100
# Out:
# 4.692893505623998

# %% [markdown]
# The mean absolute error is 4.69 percent that means the prediction is more than 95% correct.

# %% [markdown]
# 2) Random Forest Classifier: We will now implement a classification model

# %% [markdown]
# Here we will have to convert the dependent vairable into a binary variable 0 or 1

# %%
mean_chance = dataset['Chance of Admit '].mean()
mean_chance
# Out:
# 0.7243499999999996

# %%
y_train_binary = (y_train > 0.72).astype(int)
y_test_binary = (y_test > 0.72).astype(int)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RF_model = RandomForestClassifier(n_estimators=100,max_depth=7,random_state=0)
RF_model.fit(X_train, y_train_binary)
# Out:
# RandomForestClassifier(max_depth=7, random_state=0)

# %%
y_predict = RF_model.predict(X_test)
from sklearn.metrics import accuracy_score
RF_model_score = (accuracy_score(y_test_binary, y_predict))*100
RF_model_score
# Out:
# 87.5
